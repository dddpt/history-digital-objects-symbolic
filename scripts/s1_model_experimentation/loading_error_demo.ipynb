# %% [markdown]
# # Loading images and matching them to metadata

# %%
#@title Imports and function definitions


# For running inference on the TF-Hub module.
import tensorflow as tf

import tensorflow_hub as hub

# For downloading the image.
import matplotlib.pyplot as plt
import tempfile
from six.moves.urllib.request import urlopen
from six import BytesIO

# For drawing onto the image.
import numpy as np
from PIL import Image
from PIL import ImageColor
from PIL import ImageDraw
from PIL import ImageFont
from PIL import ImageOps

# For measuring the inference time.
import time

# Print Tensorflow version
print(tf.__version__)

# Check available GPU devices.
print("The following GPU devices are available: %s" % tf.test.gpu_device_name())
# Out:
# 2022-04-26 11:26:27.130076: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2.4.1
# The following GPU devices are available: /device:GPU:0
# 2022-04-26 11:26:31.833618: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
tf.test.gpu_device_name()
# Out:
# 2022-04-26 11:26:31.838377: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-04-26 11:26:32.262196: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:04:00.0 name: NVIDIA GeForce GTX TITAN X computeCapability: 5.2
# coreClock: 1.076GHz coreCount: 24 deviceMemorySize: 11.93GiB deviceMemoryBandwidth: 313.37GiB/s
# 2022-04-26 11:26:32.263062: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:83:00.0 name: NVIDIA GeForce GTX TITAN X computeCapability: 5.2
# coreClock: 1.076GHz coreCount: 24 deviceMemorySize: 11.93GiB deviceMemoryBandwidth: 313.37GiB/s
# 2022-04-26 11:26:32.263177: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-04-26 11:26:32.285876: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-04-26 11:26:32.286024: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-04-26 11:26:32.307839: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-04-26 11:26:32.308697: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-04-26 11:26:32.329872: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-04-26 11:26:32.331918: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-04-26 11:26:32.355602: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-04-26 11:26:32.358923: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1
# 2022-04-26 11:26:32.359050: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-04-26 11:26:34.234982: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-04-26 11:26:34.235049: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0 1
# 2022-04-26 11:26:34.235060: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N N
# 2022-04-26 11:26:34.235067: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 1:   N N
# 2022-04-26 11:26:34.239637: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/device:GPU:0 with 11279 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX TITAN X, pci bus id: 0000:04:00.0, compute capability: 5.2)
# 2022-04-26 11:26:34.241587: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/device:GPU:1 with 2773 MB memory) -> physical GPU (device: 1, name: NVIDIA GeForce GTX TITAN X, pci bus id: 0000:83:00.0, compute capability: 5.2)
# 2022-04-26 11:26:34.243606: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-04-26 11:26:34.280905: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:04:00.0 name: NVIDIA GeForce GTX TITAN X computeCapability: 5.2
# coreClock: 1.076GHz coreCount: 24 deviceMemorySize: 11.93GiB deviceMemoryBandwidth: 313.37GiB/s
# 2022-04-26 11:26:34.281785: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:83:00.0 name: NVIDIA GeForce GTX TITAN X computeCapability: 5.2
# coreClock: 1.076GHz coreCount: 24 deviceMemorySize: 11.93GiB deviceMemoryBandwidth: 313.37GiB/s
# 2022-04-26 11:26:34.281907: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-04-26 11:26:34.281979: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-04-26 11:26:34.282021: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-04-26 11:26:34.282051: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-04-26 11:26:34.282089: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-04-26 11:26:34.282126: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-04-26 11:26:34.282162: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-04-26 11:26:34.282197: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-04-26 11:26:34.289747: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1
# 2022-04-26 11:26:34.289838: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-04-26 11:26:34.289850: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0 1
# 2022-04-26 11:26:34.289859: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N N
# 2022-04-26 11:26:34.289865: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 1:   N N
# 2022-04-26 11:26:34.292402: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/device:GPU:0 with 11279 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX TITAN X, pci bus id: 0000:04:00.0, compute capability: 5.2)
# 2022-04-26 11:26:34.293045: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/device:GPU:1 with 2773 MB memory) -> physical GPU (device: 1, name: NVIDIA GeForce GTX TITAN X, pci bus id: 0000:83:00.0, compute capability: 5.2)
# 2022-04-26 11:26:34.293087: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# '/device:GPU:0'

# %%
# adds scripts/ and src/ folder: so you can import scripts/functions across project steps
import sys 
sys.path.append("../../src")
sys.path.append("../../scripts")

from os import listdir
from os import path

import pandas as pd
from tqdm.notebook import tqdm

from data_filepaths import image_folders, portraits_csv

# %% [markdown]
# ## Linking portraits' metadata with their path

# %% [markdown]
# #### Loading portraits' metadata

# %%
portraits = pd.read_csv(portraits_csv)
portraits.head()
# Out:
#    Unnamed: 0         artist    date          genre  pixelsx  pixelsy  \
# 0      101881       Masaccio  1420.0  self-portrait    338.0    480.0
# 1       20989       Masaccio  1425.0       portrait    999.0   1300.0
# 2       70345       Masaccio  1425.0       portrait    548.0    800.0
# 3       12749  Robert Campin  1430.0       portrait   1256.0   1857.0
# 4        2904  Robert Campin  1430.0       portrait   2024.0   3019.0
#
#    size_bytes   source                 style                      title  \
# 0     18747.0  wikiart     Early Renaissance               Self portait
# 1    899549.0  wikiart     Early Renaissance  Portrait of a Young Woman
# 2    116190.0  wikiart     Early Renaissance    Portrait of a Young Man
# 3    219654.0  wikiart  Northern Renaissance        Portrait of a Woman
# 4    416418.0  wikiart  Northern Renaissance          Portrait of a Man
#
#   artist_group  in_train new_filename  correcteddate
# 0   train_only      True    85505.jpg         1420.0
# 1   train_only      True    80100.jpg         1425.0
# 2   train_only      True    34161.jpg         1425.0
# 3    test_only     False    85550.jpg         1430.0
# 4    test_only     False     2662.jpg         1430.0

# %% [markdown]
# #### Getting images paths

# %%
image_folder = image_folders[0]
train0 = listdir(image_folder)
train0 = train0#[0:10] # SMALL SELECTION

image_paths = pd.DataFrame({
    "new_filename":train0,
    "path": [path.join(image_folder, n) for n in train0]
})

image_paths
# Out:
#       new_filename                                               path
# 0        93571.jpg  ../../data/kaggle_painters_by_numbers/train/93...
# 1        90123.jpg  ../../data/kaggle_painters_by_numbers/train/90...
# 2        71660.jpg  ../../data/kaggle_painters_by_numbers/train/71...
# 3        11898.jpg  ../../data/kaggle_painters_by_numbers/train/11...
# 4        73354.jpg  ../../data/kaggle_painters_by_numbers/train/73...
# ...            ...                                                ...
# 79428    46349.jpg  ../../data/kaggle_painters_by_numbers/train/46...
# 79429    10051.jpg  ../../data/kaggle_painters_by_numbers/train/10...
# 79430    12831.jpg  ../../data/kaggle_painters_by_numbers/train/12...
# 79431    12678.jpg  ../../data/kaggle_painters_by_numbers/train/12...
# 79432    93370.jpg  ../../data/kaggle_painters_by_numbers/train/93...
#
# [79433 rows x 2 columns]

# %%
portraits_path = image_paths.merge(portraits, on = 'new_filename', how = 'inner')
portraits_path.shape
# Out:
# (12926, 15)

# %% [markdown]
# # Object detection:

# %% [markdown]
# # ERROR: using model FasterRCNN+InceptionResNet V2 implies an error at detection
#
# To avoid the error, run it using the ssd+mobilenet V2 model

# %%
#module_handle = "https://tfhub.dev/google/openimages_v4/ssd/mobilenet_v2/1" # model ssd+mobilenet V2: small and fast.
module_handle = "https://tfhub.dev/google/faster_rcnn/openimages_v4/inception_resnet_v2/1" # model FasterRCNN+InceptionResNet V2: higher accuracy,
detector = hub.load(module_handle).signatures['default']
# Out:
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# 2022-04-12 12:48:45.350940: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-04-12 12:48:45.352275: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:04:00.0 name: NVIDIA GeForce GTX TITAN X computeCapability: 5.2
# coreClock: 1.076GHz coreCount: 24 deviceMemorySize: 11.93GiB deviceMemoryBandwidth: 313.37GiB/s
# 2022-04-12 12:48:45.353321: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:83:00.0 name: NVIDIA GeForce GTX TITAN X computeCapability: 5.2
# coreClock: 1.076GHz coreCount: 24 deviceMemorySize: 11.93GiB deviceMemoryBandwidth: 313.37GiB/s
# 2022-04-12 12:48:45.353382: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-04-12 12:48:45.353432: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-04-12 12:48:45.353457: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-04-12 12:48:45.353481: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-04-12 12:48:45.353504: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-04-12 12:48:45.353525: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-04-12 12:48:45.353549: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-04-12 12:48:45.353572: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-04-12 12:48:45.356416: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1
# 2022-04-12 12:48:45.357723: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:04:00.0 name: NVIDIA GeForce GTX TITAN X computeCapability: 5.2
# coreClock: 1.076GHz coreCount: 24 deviceMemorySize: 11.93GiB deviceMemoryBandwidth: 313.37GiB/s
# 2022-04-12 12:48:45.358778: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:83:00.0 name: NVIDIA GeForce GTX TITAN X computeCapability: 5.2
# coreClock: 1.076GHz coreCount: 24 deviceMemorySize: 11.93GiB deviceMemoryBandwidth: 313.37GiB/s
# 2022-04-12 12:48:45.358824: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-04-12 12:48:45.358866: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-04-12 12:48:45.358885: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-04-12 12:48:45.358903: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-04-12 12:48:45.358919: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-04-12 12:48:45.358936: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-04-12 12:48:45.358953: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-04-12 12:48:45.358971: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-04-12 12:48:45.361768: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1
# 2022-04-12 12:48:45.361913: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-04-12 12:48:45.361924: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0 1
# 2022-04-12 12:48:45.361931: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N N
# 2022-04-12 12:48:45.361942: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 1:   N N
# 2022-04-12 12:48:45.364009: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 865 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX TITAN X, pci bus id: 0000:04:00.0, compute capability: 5.2)
# 2022-04-12 12:48:45.365178: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 11279 MB memory) -> physical GPU (device: 1, name: NVIDIA GeForce GTX TITAN X, pci bus id: 0000:83:00.0, compute capability: 5.2)
# 2022-04-12 12:48:45.365215: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-04-12 12:48:45.951481: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-04-12 12:48:45.972475: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2494185000 Hz

# %%
IMAGE_RESIZE_SHAPE = 2* [256]

def display_image(image):
  fig = plt.figure(figsize=(20, 15))
  plt.grid(False)
  plt.imshow(image)


def load_and_resize_image(path, new_width=IMAGE_RESIZE_SHAPE[0], new_height=IMAGE_RESIZE_SHAPE[1],
                              display=False):
  _, filename = tempfile.mkstemp(suffix=".jpg")
  pil_image = Image.open(path)
  pil_image = ImageOps.fit(pil_image, (new_width, new_height), Image.ANTIALIAS)
  pil_image_rgb = pil_image.convert("RGB")
  pil_image_rgb.save(filename, format="JPEG", quality=90)
  print("Image downloaded to %s." % filename)
  if display:
    display_image(pil_image)
  return filename


def draw_bounding_box_on_image(image,
                               ymin,
                               xmin,
                               ymax,
                               xmax,
                               color,
                               font,
                               thickness=4,
                               display_str_list=()):
  """Adds a bounding box to an image."""
  draw = ImageDraw.Draw(image)
  im_width, im_height = image.size
  (left, right, top, bottom) = (xmin * im_width, xmax * im_width,
                                ymin * im_height, ymax * im_height)
  draw.line([(left, top), (left, bottom), (right, bottom), (right, top),
             (left, top)],
            width=thickness,
            fill=color)

  # If the total height of the display strings added to the top of the bounding
  # box exceeds the top of the image, stack the strings below the bounding box
  # instead of above.
  display_str_heights = [font.getsize(ds)[1] for ds in display_str_list]
  # Each display_str has a top and bottom margin of 0.05x.
  total_display_str_height = (1 + 2 * 0.05) * sum(display_str_heights)

  if top > total_display_str_height:
    text_bottom = top
  else:
    text_bottom = top + total_display_str_height
  # Reverse list and print from bottom to top.
  for display_str in display_str_list[::-1]:
    text_width, text_height = font.getsize(display_str)
    margin = np.ceil(0.05 * text_height)
    draw.rectangle([(left, text_bottom - text_height - 2 * margin),
                    (left + text_width, text_bottom)],
                   fill=color)
    draw.text((left + margin, text_bottom - text_height - margin),
              display_str,
              fill="black",
              font=font)
    text_bottom -= text_height - 2 * margin


def draw_boxes(image, boxes, class_names, scores, max_boxes=10, min_score=0.1):
  """Overlay labeled boxes on an image with formatted scores and label names."""
  colors = list(ImageColor.colormap.values())

  try:
    font = ImageFont.truetype("/usr/share/fonts/truetype/liberation/LiberationSansNarrow-Regular.ttf",
                              25)
  except IOError:
    print("Font not found, using default font.")
    font = ImageFont.load_default()

  for i in range(min(boxes.shape[0], max_boxes)):
    if scores[i] >= min_score:
      ymin, xmin, ymax, xmax = tuple(boxes[i])
      display_str = "{}: {}%".format(class_names[i].decode("ascii"),
                                     int(100 * scores[i]))
      color = colors[hash(class_names[i]) % len(colors)]
      image_pil = Image.fromarray(np.uint8(image)).convert("RGB")
      draw_bounding_box_on_image(
          image_pil,
          ymin,
          xmin,
          ymax,
          xmax,
          color,
          font,
          display_str_list=[display_str])
      np.copyto(image, np.array(image_pil))
  return image, image_pil

# %%
def load_img(path):
  
  img = tf.io.read_file(path)
  img = tf.image.decode_jpeg(img, channels=3)
  return img

# %%
def run_detector(detector, path, display=True):
  img = load_img(path)

  converted_img  = tf.image.convert_image_dtype(img, tf.float32)[tf.newaxis, ...]
  start_time = time.time()
  result = detector(converted_img)
  end_time = time.time()

  result = {key:value.numpy() for key,value in result.items()}

  print("Found %d objects." % len(result["detection_scores"]))
  print("Inference time: ", end_time-start_time)

  image_with_boxes, image_with_boxes_pil = draw_boxes(
      img.numpy(), result["detection_boxes"],
      result["detection_class_entities"], result["detection_scores"])

  if display:
    display_image(image_with_boxes)
  return image_with_boxes_pil, result

# %%
#for image_path in image_paths.path:
#    run_detector(detector, image_path)

# %%
portraits_path.path[0]
# Out:
# '../../data/kaggle_painters_by_numbers/train/50598.jpg'

# %%
image = load_img(portraits_path.path[0])
display_image(image)

# %%
resized_image_path = load_and_resize_image(portraits_path.path[0])
resized_image = load_img(resized_image_path)
display_image(resized_image)
# Out:
# Image downloaded to /scratch/ddupertu/.pipenv_tmpdir/tmpy1tp7wt0.jpg.

# %%
run_detector(detector, resized_image_path )
# Out:
# 2022-04-12 12:50:59.820035: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-04-12 12:51:00.561087: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-04-12 12:51:02.810999: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 807.16MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-04-12 12:51:02.826927: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.17GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-04-12 12:51:02.830874: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.57GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-04-12 12:51:02.851233: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 881.12MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-04-12 12:51:02.855164: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-04-12 12:51:02.859005: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.18GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-04-12 12:51:02.862813: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.56GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-04-12 12:51:02.881607: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 804.50MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-04-12 12:51:02.890496: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.17GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-04-12 12:51:02.899632: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.33GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-04-12 12:51:13.565112: W tensorflow/core/common_runtime/bfc_allocator.cc:433] Allocator (GPU_0_bfc) ran out of memory trying to allocate 359.84MiB (rounded to 377318400)requested by op MaxPool2D/MaxPool-0-TransposeNHWCToNCHW-LayoutOptimizer
# Current allocation summary follows.
# 2022-04-12 12:51:13.565894: I tensorflow/core/common_runtime/bfc_allocator.cc:972] BFCAllocator dump for GPU_0_bfc
# 2022-04-12 12:51:13.566098: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (256): 	Total Chunks: 836, Chunks in use: 836. 209.0KiB allocated for chunks. 209.0KiB in use in bin. 35.8KiB client-requested in use in bin.
# 2022-04-12 12:51:13.566269: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (512): 	Total Chunks: 320, Chunks in use: 320. 221.2KiB allocated for chunks. 221.2KiB in use in bin. 211.6KiB client-requested in use in bin.
# 2022-04-12 12:51:13.566449: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (1024): 	Total Chunks: 109, Chunks in use: 109. 119.5KiB allocated for chunks. 119.5KiB in use in bin. 114.5KiB client-requested in use in bin.
# 2022-04-12 12:51:13.566615: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (2048): 	Total Chunks: 2, Chunks in use: 2. 5.5KiB allocated for chunks. 5.5KiB in use in bin. 5.4KiB client-requested in use in bin.
# 2022-04-12 12:51:13.566780: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (4096): 	Total Chunks: 26, Chunks in use: 25. 119.8KiB allocated for chunks. 113.8KiB in use in bin. 111.4KiB client-requested in use in bin.
# 2022-04-12 12:51:13.566949: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (8192): 	Total Chunks: 11, Chunks in use: 11. 92.0KiB allocated for chunks. 92.0KiB in use in bin. 90.6KiB client-requested in use in bin.
# 2022-04-12 12:51:13.567130: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (16384): 	Total Chunks: 1, Chunks in use: 1. 20.0KiB allocated for chunks. 20.0KiB in use in bin. 20.0KiB client-requested in use in bin.
# 2022-04-12 12:51:13.567295: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (32768): 	Total Chunks: 55, Chunks in use: 55. 2.26MiB allocated for chunks. 2.26MiB in use in bin. 2.26MiB client-requested in use in bin.
# 2022-04-12 12:51:13.567463: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (65536): 	Total Chunks: 13, Chunks in use: 13. 1.29MiB allocated for chunks. 1.29MiB in use in bin. 1.29MiB client-requested in use in bin.
# 2022-04-12 12:51:13.567639: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (131072): 	Total Chunks: 12, Chunks in use: 12. 1.96MiB allocated for chunks. 1.96MiB in use in bin. 1.96MiB client-requested in use in bin.
# 2022-04-12 12:51:13.567809: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (262144): 	Total Chunks: 12, Chunks in use: 12. 5.35MiB allocated for chunks. 5.35MiB in use in bin. 5.35MiB client-requested in use in bin.
# 2022-04-12 12:51:13.567980: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (524288): 	Total Chunks:
I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 4216c1a800 of size 40960 next 294
# 2022-04-12 12:51:13.606734: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 4216c24800 of size 256 next 295
# 2022-04-12 12:51:13.606754: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 4216c24900 of size 256 next 296
# 2022-04-12 12:51:13.606771: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 4216c24a00 of size 256 next 297
# 2022-04-12 12:51:13.606790: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 4216c24b00 of size 36864 next 298
# 2022-04-12 12:51:13.606811: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 4216c2db00 of size 256 next 299
# 2022-04-12 12:51:13.606824: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 4216c2dc00 of size 256 next 300
# 2022-04-12 12:51:13.606839: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 4216c2dd00 of size 256 next 301
# 2022-04-12 12:51:13.606855: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 4216c2de00 of size 40960 next 302
# 2022-04-12 12:51:13.606871: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 4216c37e00 of size 256 next 303
# 2022-04-12 12:51:13.606901: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 4216c37f00 of size 256 next 304
# 2022-04-12 12:51:13.606923: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 4216c38000 of size 256 next 305
# 2022-04-12 12:51:13.606945: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 4216c38100 of size 55296 next 306
# 2022-04-12 12:51:13.606967: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 4216c45900 of size 256 next 307
# 2022-04-12 12:51:13.606986: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 4216c45a00 of size 256 next 308
# 2022-04-12 12:51:13.606999: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 4216c45b00 of size 256 next 309
# 2022-04-12 12:51:13.607024: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 4216c45c00 of size 110592 next 310
# ...
# 2022-04-12 12:51:13.965892: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 14770176 totalling 14.09MiB
# 2022-04-12 12:51:13.966040: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 20054016 totalling 19.12MiB
# 2022-04-12 12:51:13.966054: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 377318400 totalling 359.84MiB
# 2022-04-12 12:51:13.966064: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Sum Total of in-use chunks: 609.54MiB
# 2022-04-12 12:51:13.966073: I tensorflow/core/common_runtime/bfc_allocator.cc:1042] total_region_allocated_bytes_: 907935744 memory_limit_: 907935744 available bytes: 0 curr_region_allocation_bytes_: 1815871488
# 2022-04-12 12:51:13.966088: I tensorflow/core/common_runtime/bfc_allocator.cc:1048] Stats:
# Limit:                       907935744
# InUse:                       639145728
# MaxInUse:                    907933440
# NumAllocs:                        3984
# MaxAllocSize:                604212224
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-04-12 12:51:13.966194: W tensorflow/core/common_runtime/bfc_allocator.cc:441] *****************************_*__*******************************************________________________
# 2022-04-12 12:51:13.966337: W tensorflow/core/framework/op_kernel.cc:1763] OP_REQUIRES failed at transpose_op.cc:184 : Resource exhausted: OOM when allocating tensor with shape[300,1088,17,17] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /scratch/ddupertu/history-digital-objects-symbolic/scripts/s1_model_experimentation/loading_error_demo.ipynb Cell 22' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Biccluster040.iccluster.epfl.ch/scratch/ddupertu/history-digital-objects-symbolic/scripts/s1_model_experimentation/loading_error_demo.ipynb#ch0000021vscode-remote?line=0'>1</a> run_detector(detector, resized_image_path )
#
# /scratch/ddupertu/history-digital-objects-symbolic/scripts/s1_model_experimentation/loading_error_demo.ipynb Cell 16' in run_detector(detector, path, display)
#       <a href='vscode-notebook-cell://ssh-remote%2Biccluster040.iccluster.epfl.ch/scratch/ddupertu/history-digital-objects-symbolic/scripts/s1_model_experimentation/loading_error_demo.ipynb#ch0000015vscode-remote?line=3'>4</a> converted_img  = tf.image.convert_image_dtype(img, tf.float32)[tf.newaxis, ...]
#       <a href='vscode-notebook-cell://ssh-remote%2Biccluster040.iccluster.epfl.ch/scratch/ddupertu/history-digital-objects-symbolic/scripts/s1_model_experimentation/loading_error_demo.ipynb#ch0000015vscode-remote?line=4'>5</a> start_time = time.time()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Biccluster040.iccluster.epfl.ch/scratch/ddupertu/history-digital-objects-symbolic/scripts/s1_model_experimentation/loading_error_demo.ipynb#ch0000015vscode-remote?line=5'>6</a> result = detector(converted_img)
#       <a href='vscode-notebook-cell://ssh-remote%2Biccluster040.iccluster.epfl.ch/scratch/ddupertu/history-digital-objects-symbolic/scripts/s1_model_experimentation/loading_error_demo.ipynb#ch0000015vscode-remote?line=6'>7</a> end_time = time.time()
#       <a href='vscode-notebook-cell://ssh-remote%2Biccluster040.iccluster.epfl.ch/scratch/ddupertu/history-digital-objects-symbolic/scripts/s1_model_experimentation/loading_error_demo.ipynb#ch0000015vscode-remote?line=8'>9</a> result = {key:value.numpy() for key,value in result.items()}
#
# File /scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py:1669, in ConcreteFunction.__call__(self, *args, **kwargs)
#    <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1618'>1619</a> def __call__(self, *args, **kwargs):
#    <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1619'>1620</a>   """Executes the wrapped function.
#    <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1620'>1621</a>
#    <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1621'>1622</a>   ConcreteFunctions have two signatures:
#    (...)
#    <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1666'>1667</a>     TypeError: If the arguments do not match the function's signature.
#    <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1667'>1668</a>   """
# -> <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1668'>1669</a>   return self._call_impl(args, kwargs)
#
# File /scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/wrap_function.py:246, in WrappedFunction._call_impl(self, args, kwargs, cancellation_manager)
#     <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/wrap_function.py?line=243'>244</a>   return self._call_flat(args, self.captured_inputs)
#     <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/wrap_function.py?line=244'>245</a> else:
# --> <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/wrap_function.py?line=245'>246</a>   return super(WrappedFunction, self)._call_impl(
#     <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/wrap_function.py?line=246'>247</a>       args, kwargs, cancellation_manager)
#
# File /scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py:1687, in ConcreteFunction._call_impl(self, args, kwargs, cancellation_manager)
#    <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1683'>1684</a>     except TypeError:
#    <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1684'>1685</a>       raise structured_err
# -> <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1686'>1687</a> return self._call_with_flat_signature(args, kwargs, cancellation_manager)
#
# File /scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py:1736, in ConcreteFunction._call_with_flat_signature(self, args, kwargs, cancellation_manager)
#    <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1730'>1731</a>   if not isinstance(
#    <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1731'>1732</a>       arg, (ops.Tensor, resource_variable_ops.BaseResourceVariable)):
#    <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1732'>1733</a>     raise TypeError("{}: expected argument #{}(zero-based) to be a Tensor; "
#    <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1733'>1734</a>                     "got {} ({})".format(self._flat_signature_summary(), i,
#    <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1734'>1735</a>                                          type(arg).__name__, str(arg)))
# -> <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1735'>1736</a> return self._call_flat(args, self.captured_inputs, cancellation_manager)
#
# File /scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py:1918, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1913'>1914</a> possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1914'>1915</a> if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1915'>1916</a>     and executing_eagerly):
#    <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1916'>1917</a>   # No tape is watching; skip to running the function.
# -> <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1917'>1918</a>   return self._build_call_outputs(self._inference_function.call(
#    <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1918'>1919</a>       ctx, args, cancellation_manager=cancellation_manager))
#    <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1919'>1920</a> forward_backward = self._select_forward_and_backward_functions(
#    <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1920'>1921</a>     args,
#    <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1921'>1922</a>     possible_gradient_type,
#    <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1922'>1923</a>     executing_eagerly)
#    <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1923'>1924</a> forward_function, args_with_tangents = forward_backward.forward()
#
# File /scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py:555, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=552'>553</a> with _InterpolateFunctionError(self):
#     <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=553'>554</a>   if cancellation_manager is None:
# --> <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=554'>555</a>     outputs = execute.execute(
#     <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=555'>556</a>         str(self.signature.name),
#     <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=556'>557</a>         num_outputs=self._num_outputs,
#     <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=557'>558</a>         inputs=args,
#     <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=558'>559</a>         attrs=attrs,
#     <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=559'>560</a>         ctx=ctx)
#     <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=560'>561</a>   else:
#     <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=561'>562</a>     outputs = execute.execute_with_cancellation(
#     <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=562'>563</a>         str(self.signature.name),
#     <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=563'>564</a>         num_outputs=self._num_outputs,
#    (...)
#     <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=566'>567</a>         ctx=ctx,
#     <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=567'>568</a>         cancellation_manager=cancellation_manager)
#
# File /scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/execute.py:59, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/execute.py?line=56'>57</a> try:
#      <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/execute.py?line=57'>58</a>   ctx.ensure_initialized()
# ---> <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/execute.py?line=58'>59</a>   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/execute.py?line=59'>60</a>                                       inputs, attrs, num_outputs)
#      <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/execute.py?line=60'>61</a> except core._NotOkStatusException as e:
#      <a href='file:///scratch/ddupertu/.conda/envs/history-digital/lib/python3.8/site-packages/tensorflow/python/eager/execute.py?line=61'>62</a>   if name is not None:
#
# ResourceExhaustedError: 2 root error(s) found.
#   (0) Resource exhausted:  OOM when allocating tensor with shape[300,1088,17,17] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node MaxPool2D/MaxPool-0-TransposeNHWCToNCHW-LayoutOptimizer}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 	 [[SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/Switch_1/_218]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#   (1) Resource exhausted:  OOM when allocating tensor with shape[300,1088,17,17] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node MaxPool2D/MaxPool-0-TransposeNHWCToNCHW-LayoutOptimizer}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_pruned_176717]
#
# Function call stack:
# pruned -> pruned

# %%
image_with_boxes, result = run_detector(detector, portraits_path.path[0])
# Out:
# Found 100 objects.
# Inference time:  0.27216029167175293
# Font not found, using default font.

# %%
image_with_boxes.save("test.jpg", format="JPEG", quality=90)

# %%
gresult = None
for i, img_path in enumerate(portraits_path.path[0:1]):
    print(f"\n\niteration {i}\n-----------------")
    image_with_boxes, result = run_detector(detector, img_path, display=False)
    gresult=result
    image_with_boxes.save(f"portrait_{i}.jpg", format="JPEG", quality=90)
# Out:
# iteration 0
# -----------------
# Found 100 objects.
# Inference time:  0.43424248695373535
# Font not found, using default font.

# %%
gresult.keys()
# Out:
# dict_keys(['detection_class_labels', 'detection_class_names', 'detection_class_entities', 'detection_scores', 'detection_boxes'])

# %%
gresult["detection_class_entities"]
# Out:
# array([b'Person', b'Clothing', b'Human face', b'Person', b'Person',
#        b'Person', b'Clothing', b'Clothing', b'Clothing', b'Clothing',
#        b'Clothing', b'Person', b'Clothing', b'Clothing', b'Clothing',
#        b'Clothing', b'Human face', b'Clothing', b'Clothing', b'Person',
#        b'Human face', b'Clothing', b'Human face', b'Human face',
#        b'Human face', b'Clothing', b'Clothing', b'Clothing', b'Clothing',
#        b'Clothing', b'Clothing', b'Clothing', b'Clothing', b'Clothing',
#        b'Clothing', b'Clothing', b'Clothing', b'Clothing', b'Clothing',
#        b'Clothing', b'Footwear', b'Clothing', b'Person', b'Person',
#        b'Clothing', b'Person', b'Person', b'Clothing', b'Person',
#        b'Clothing', b'Clothing', b'Clothing', b'Person', b'Human face',
#        b'Person', b'Footwear', b'Clothing', b'Clothing', b'Clothing',
#        b'Clothing', b'Human face', b'Clothing', b'Person', b'Person',
#        b'Clothing', b'Clothing', b'Clothing', b'Human face', b'Man',
#        b'Clothing', b'Clothing', b'Clothing', b'Human face', b'Clothing',
#        b'Clothing', b'Clothing', b'Human face', b'Clothing', b'Person',
#        b'Clothing', b'Human face', b'Clothing', b'Person', b'Clothing',
#        b'Clothing', b'Clothing', b'Human face', b'Person', b'Clothing',
#        b'Human face', b'Clothing', b'Clothing', b'Clothing', b'Clothing',
#        b'Person', b'Clothing', b'Footwear', b'Person', b'Clothing',
#        b'Clothing'], dtype=object)

# %%
gresult["detection_scores"]
# Out:
# array([0.2945666 , 0.19028904, 0.17744839, 0.14059009, 0.13896129,
#        0.13332061, 0.13227126, 0.13004462, 0.12147187, 0.11898179,
#        0.1176649 , 0.11684156, 0.11646194, 0.11438151, 0.11417153,
#        0.11408911, 0.11098552, 0.1058634 , 0.10526484, 0.10327458,
#        0.10301409, 0.10280191, 0.10258266, 0.10257877, 0.10256747,
#        0.1019573 , 0.10132176, 0.09988759, 0.09884749, 0.09805095,
#        0.09746286, 0.09741983, 0.09695796, 0.09677725, 0.09500758,
#        0.09437758, 0.0941142 , 0.09351376, 0.09308514, 0.09249114,
#        0.09169127, 0.09142539, 0.09110105, 0.08989624, 0.08958478,
#        0.08952472, 0.08873003, 0.08849107, 0.0876186 , 0.08752216,
#        0.08664685, 0.08652073, 0.0853722 , 0.08519799, 0.08498275,
#        0.08476309, 0.08459622, 0.08436419, 0.0841959 , 0.08382493,
#        0.08369046, 0.08356472, 0.08283266, 0.08279821, 0.08236117,
#        0.081769  , 0.08172825, 0.08106099, 0.08080951, 0.08062272,
